# %%
import numpy as np
import pandas as pd

# %%
from data_io import *

# %%
df = read_file('../data/ctg-studies.csv')
df.head()
# Out:
#     NCT Number                                        Study Title  \
# 0  NCT04919512  A Study of TAR-200 in Combination With Cetreli...
# 1  NCT04658862  A Study of TAR-200 in Combination With Cetreli...
# 2  NCT04640623  A Study of TAR-200 in Combination With Cetreli...
# 3  NCT04241185  Efficacy and Safety of Pembrolizumab (MK-3475)...
# 4  NCT04172675  A Study of Erdafitinib Versus Investigator Cho...
#
#                                       Study URL           Study Status  \
# 0  https://clinicaltrials.gov/study/NCT04919512  ACTIVE_NOT_RECRUITING
# 1  https://clinicaltrials.gov/study/NCT04658862  ACTIVE_NOT_RECRUITING
# 2  https://clinicaltrials.gov/study/NCT04640623  ACTIVE_NOT_RECRUITING
# 3  https://clinicaltrials.gov/study/NCT04241185  ACTIVE_NOT_RECRUITING
# 4  https://clinicaltrials.gov/study/NCT04172675              COMPLETED
#
#   Study Results                 Conditions  \
# 0            NO  Urinary Bladder Neoplasms
# 1            NO  Urinary Bladder Neoplasms
# ...

# %%
# df.isna().sum()
df.dtypes
# Out:
# NCT Number                 object
# Study Title                object
# Study URL                  object
# Study Status               object
# Study Results              object
# Conditions                 object
# Interventions              object
# Sponsor                    object
# Phases                     object
# Start Date                 object
# Primary Completion Date    object
# Completion Date            object
# First Posted               object
# Results First Posted       object
# Last Update Posted         object
# dtype: object
